# %%
import matplotlib.pyplot as plt
# Function to find 3-pos-kristalle along with their original indices
def find_3_pos_kristalle(data, original_indices):
    kristalle = []
    indices = []
    for i in range(len(data)):
        if i == 0 and data[i] > data[i + 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
        elif i == len(data) - 1 and data[i] > data[i - 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
        elif i > 0 and i < len(data) - 1 and data[i] > data[i - 1] and data[i] > data[i + 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
    return kristalle, indices

# Function to find 3-neg-kristalle along with their original indices
def find_3_neg_kristalle(data, original_indices):
    kristalle = []
    indices = []
    for i in range(len(data)):
        if i == 0 and data[i] < data[i + 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
        elif i == len(data) - 1 and data[i] < data[i - 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
        elif i > 0 and i < len(data) - 1 and data[i] < data[i - 1] and data[i] < data[i + 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
    return kristalle, indices
# Function to find the lowest point between two peaks
def find_valley_between_peaks(data, start_index, end_index):
    return min(data[start_index + 1:end_index]), start_index + np.argmin(data[start_index + 1:end_index])

# Function to find the highest point between two valleys
def find_peak_between_valleys(data, start_index, end_index):
    return max(data[start_index + 1:end_index]), start_index + np.argmax(data[start_index + 1:end_index])

# Initial data
data = df['close'].values
original_indices = list(range(len(data)))

# Applying the functions iteratively until only 2 pos-kristalle and neg-kristalle are left
pos_kristalle, pos_indices = find_3_pos_kristalle(data, original_indices)
neg_kristalle, neg_indices = find_3_neg_kristalle(data, original_indices)

while len(pos_kristalle) > 20:
    pos_kristalle, pos_indices = find_3_pos_kristalle(pos_kristalle, pos_indices)

while len(neg_kristalle) > 20:
    neg_kristalle, neg_indices = find_3_neg_kristalle(neg_kristalle, neg_indices)

# Plotting the original 'close' data with the final pos-kristalle and neg-kristalle
plt.figure(figsize=[12,6])
plt.plot(data, label='Close Price')
plt.scatter(pos_indices, pos_kristalle, color='red', label='Final 3-pos-kristalle (2 remaining)')
plt.scatter(neg_indices, neg_kristalle, color='green', label='Final 3-neg-kristalle (2 remaining)')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.title('Close Price with Final 3-pos-kristalle and 3-neg-kristalle')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Function to find 3-pos-kristalle along with their original indices
def find_3_pos_kristalle(data, original_indices):
    kristalle = []
    indices = []
    for i in range(len(data)):
        if i == 0 and data[i] > data[i + 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
        elif i == len(data) - 1 and data[i] > data[i - 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
        elif i > 0 and i < len(data) - 1 and data[i] > data[i - 1] and data[i] > data[i + 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
    return kristalle, indices

# Function to find 3-neg-kristalle along with their original indices
def find_3_neg_kristalle(data, original_indices):
    kristalle = []
    indices = []
    for i in range(len(data)):
        if i == 0 and data[i] < data[i + 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
        elif i == len(data) - 1 and data[i] < data[i - 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
        elif i > 0 and i < len(data) - 1 and data[i] < data[i - 1] and data[i] < data[i + 1]:
            kristalle.append(data[i])
            indices.append(original_indices[i])
    return kristalle, indices
# Function to find the lowest point between two peaks
def find_valley_between_peaks(data, start_index, end_index):
    return min(data[start_index + 1:end_index]), start_index + np.argmin(data[start_index + 1:end_index])

# Function to find the highest point between two valleys
def find_peak_between_valleys(data, start_index, end_index):
    return max(data[start_index + 1:end_index]), start_index + np.argmax(data[start_index + 1:end_index])
# Reinitializing the pos_kristalle and neg_kristalle
pos_kristalle, pos_indices = find_3_pos_kristalle(data, original_indices)
neg_kristalle, neg_indices = find_3_neg_kristalle(data, original_indices)

while len(pos_kristalle) > 3:
    pos_kristalle, pos_indices = find_3_pos_kristalle(pos_kristalle, pos_indices)

while len(neg_kristalle) > 3:
    neg_kristalle, neg_indices = find_3_neg_kristalle(neg_kristalle, neg_indices)

# Add valleys between peaks if there is no valley and if there is space to look for a valley
for i in range(len(pos_indices) - 1):
    if pos_indices[i + 1] not in neg_indices and pos_indices[i] + 1 < pos_indices[i + 1]:
        valley_value, valley_index = find_valley_between_peaks(data, pos_indices[i], pos_indices[i + 1])
        neg_kristalle.append(valley_value)
        neg_indices.append(valley_index)

# Add peaks between valleys if there is no peak and if there is space to look for a peak
for i in range(len(neg_indices) - 1):
    if neg_indices[i + 1] not in pos_indices and neg_indices[i] + 1 < neg_indices[i + 1]:
        peak_value, peak_index = find_peak_between_valleys(data, neg_indices[i], neg_indices[i + 1])
        pos_kristalle.append(peak_value)
        pos_indices.append(peak_index)

# Sorting the pos_kristalle and neg_kristalle by their indices
pos_kristalle, pos_indices = zip(*sorted(zip(pos_kristalle, pos_indices)))
neg_kristalle, neg_indices = zip(*sorted(zip(neg_kristalle, neg_indices)))

# Plotting the original 'close' data with the updated pos-kristalle and neg-kristalle
plt.figure(figsize=[12,6])
plt.plot(data, label='Close Price')
plt.scatter(pos_indices, pos_kristalle, color='red', label='Updated 3-pos-kristalle')
plt.scatter(neg_indices, neg_kristalle, color='green', label='Updated 3-neg-kristalle')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.title('Close Price with Updated 3-pos-kristalle and 3-neg-kristalle')
plt.legend()
plt.show()

# %%
# Function to calculate the goodness of fit for a given set of extrema
def calculate_goodness_of_fit(extrema_indices):
    segments_comb = [data[i:j] for i, j in zip([0] + list(extrema_indices), list(extrema_indices) + [len(data)])]
    log_returns_comb = [log(segment[1:] / segment[:-1]) for segment in segments_comb if len(segment) > 1]
    analysis_results_comb = [analyze_log_returns(segment_log_returns) for segment_log_returns in log_returns_comb]
    p_values_comb = [result[3] for result in analysis_results_comb]
    return sum(p_values_comb) - min(p_values_comb) # Sum of p-values minus penalty for the worst

from itertools import combinations

# All possible combinations of 4 extrema
all_combinations = combinations(all_extrema_indices_20, 4)

# Finding the best combination of extrema
best_combination = None
best_goodness_of_fit = float('-inf')
for comb in all_combinations:
    goodness_of_fit = calculate_goodness_of_fit(comb)
    if goodness_of_fit > best_goodness_of_fit:
        best_goodness_of_fit = goodness_of_fit
        best_combination = comb

best_combination, best_goodness_of_fit

# Finding the best combination of extrema
best_combination = None
best_goodness_of_fit = float('-inf')
for comb in all_combinations:
    goodness_of_fit = calculate_goodness_of_fit(comb)
    if goodness_of_fit > best_goodness_of_fit:
        best_goodness_of_fit = goodness_of_fit
        best_combination = comb

best_combination, best_goodness_of_fit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-f697daf3b012> in <module>
#      10
#      11 # All possible combinations of 4 extrema
# ---> 12 all_combinations = combinations(all_extrema_indices_20, 4)
#      13
#      14 # Finding the best combination of extrema
#
# NameError: name 'all_extrema_indices_20' is not defined

# %%
import pandas as pd

df = pd.read_csv("3months.csv")
df.head()
# Out:
#    Unnamed: 0      open_time     open     high      low    close      volume  \
# 0           0  1682899200000  1868.41  1885.56  1867.20  1884.08  172201.437
# 1           1  1682902800000  1884.09  1884.90  1821.17  1834.90  515365.298
# 2           2  1682906400000  1834.89  1846.19  1832.21  1843.28  204270.793
# 3           3  1682910000000  1843.28  1846.74  1841.20  1845.94   98998.300
# 4           4  1682913600000  1845.94  1846.95  1841.44  1846.80   73249.415
#
#       close_time  quote_volume   count  taker_buy_volume  \
# 0  1682902799999  3.233506e+08  151242         91880.163
# 1  1682906399999  9.502794e+08  328909        236639.671
# 2  1682909999999  3.762016e+08  174011        101511.948
# 3  1682913599999  1.825534e+08   96797         50942.213
# 4  1682917199999  1.350939e+08   76832         34362.689
#
#    taker_buy_quote_volume  ignore
# 0            1.725116e+08       0
# 1            4.360779e+08       0
# 2            1.869391e+08       0
# ...

# %%
x = df.close.values
print(len(x))
for i in range(12):
    x = find_local_extrema(x)
    print(len(x))
# Out:
# 2208
# 1193
# 616
# 345
# 195
# 123
# 72
# 40
# 22
# 9
# 6
# 4
# 2

# %%
# Modifying the find_local_extrema function to return only the extrema values
def find_local_extrema(data):
    extrema = []
    # Handling elements in between
    for i in range(1, len(data) - 1):
        if (data[i] > data[i - 1] and data[i] > data[i + 1]) or (data[i] < data[i - 1] and data[i] < data[i + 1]):
            extrema.append(data[i])
    # Handling the first element
    if data[0] > data[1] or data[0] < data[1]:
        extrema.append(data[0])
    # Handling the last element
    if data[-1] > data[-2] or data[-1] < data[-2]:
        extrema.append(data[-1])
    return extrema

# Applying the function iteratively until only 4 extrema are left
x = df['close'].values
extrema_counts = [len(x)]
for i in range(4):
    print(len(x))
    x = find_local_extrema(x)
    extrema_counts.append(len(x))

extrema_counts
# Out:
# 2208
# 1193
# 1191
# 1191
# [2208, 1193, 1191, 1191, 1190]

# %%
find_local_extrema(find_local_extrema(x))
# Out:
# [1884.08,
#  1834.9,
#  1846.8,
#  1845.68,
#  1848.82,
#  1844.51,
#  1849.02,
#  1840.72,
#  1842.5,
#  1833.09,
#  1839.34,
#  1806.99,
#  1831.68,
#  1825.33,
#  1829.83,
#  1824.76,
#  1828.11,
#  1827.56,
#  1834.88,
#  1827.71,
#  1832.95,
#  1827.8,
#  1857.84,
#  1854.33,
#  1869.93,
#  1867.68,
#  1872.98,
#  1859.28,
#  1862.84,
#  1860.3,
#  1862.14,
#  1859.67,
#  1865.31,
#  1864.55,
#  1867.59,
#  1849.31,
#  1855.89,
#  1847.57,
#  1884.38,
#  1867.18,
#  1906.13,
#  1901.32,
#  1902.94,
#  1900.22,
#  1902.3,
#  1898.0,
#  1911.13,
#  1884.78,
#  1885.68,
#  1884.59,
#  1885.31,
#  1871.78,
#  1876.71,
#  1870.32,
#  1898.33,
#  1895.76,
#  1896.87,
#  1895.75,
#  1898.0,
#  1894.27,
#  1910.82,
#  1903.99,
#  1991.57,
#  1979.79,
#  1990.44,
#  1984.78,
#  2002.0,
#  1959.65,
#  1962.79,
#  1927.5,
#  1933.7,
#  1874.77,
#  1899.11,
#  1893.97,
#  1894.96,
#  1894.4,
#  1904.25,
#  1891.22,
#  1904.48,
#  1902.0,
#  1904.53,
#  1901.31,
#  1926.95,
#  1908.94,
# ...
