# %%
def find_highs(df, column_name):
    """
    Corrected function to find high points based on specified criteria.
    
    Parameters:
    - df: DataFrame containing the data
    - column_name: Name of the column to search for highs
    
    Returns:
    - highs: List of indices where high points are located
    """
    
    highs = []
    
    # First point
    if df[column_name].iloc[0] > df[column_name].iloc[1]:
        highs.append(df.index[0])
    
    # Middle points
    for i in range(1, len(df) - 1):
        if df[column_name].iloc[i] > df[column_name].iloc[i-1] and df[column_name].iloc[i] > df[column_name].iloc[i+1]:
            highs.append(df.index[i])
            
    # Last point
    if df[column_name].iloc[-1] > df[column_name].iloc[-2]:
        highs.append(df.index[-1])
    
    return highs

def find_lows(df, column_name):
    """
    Corrected function to find low points based on specified criteria.
    
    Parameters:
    - df: DataFrame containing the data
    - column_name: Name of the column to search for lows
    
    Returns:
    - lows: List of indices where low points are located
    """
    
    lows = []
    
    # First point
    if df[column_name].iloc[0] < df[column_name].iloc[1]:
        lows.append(df.index[0])
    
    # Middle points
    for i in range(1, len(df) - 1):
        if df[column_name].iloc[i] < df[column_name].iloc[i-1] and df[column_name].iloc[i] < df[column_name].iloc[i+1]:
            lows.append(df.index[i])
            
    # Last point
    if df[column_name].iloc[-1] < df[column_name].iloc[-2]:
        lows.append(df.index[-1])
    
    return lows

def refine_highs(df, column_name, target_length, min_length=2):
    """
    Refines the high points until the desired target length is achieved.

    Parameters:
    - df: DataFrame containing the data
    - column_name: Name of the column to search for highs
    - target_length: Desired number of high points

    Returns:
    - refined_highs: List of indices where refined high points are located
    """

    refined_highs = find_highs(df, column_name)

    # Keep refining the high points until the desired length is achieved
    while len(refined_highs) > target_length:
        last_refined_highs = refined_highs
        refined_highs = find_highs(df.iloc[refined_highs], column_name)
        if len(refined_highs) < min_length:
            refined_highs = last_refined_highs
            break

    return refined_highs

def refine_lows(df, column_name, target_length, min_length=2):
    """
    Refines the low points until the desired target length is achieved.

    Parameters:
    - df: DataFrame containing the data
    - column_name: Name of the column to search for lows
    - target_length: Desired number of low points

    Returns:
    - refined_lows: List of indices where refined low points are located
    """

    refined_lows = find_lows(df, column_name)
    # Keep refining the low points until the desired length is achieved
    while len(refined_lows) > target_length:
        last_refined_lows = refined_lows
        refined_lows = find_lows(df.iloc[refined_lows], column_name)
        if len(refined_lows) < min_length:
            refined_lows = last_refined_lows
            break
            
    return refined_lows

import os
import pandas as pd


extract_path = r"C:\Users\xyz\Desktop\bodi2"

df = pd.read_csv(os.path.join(extract_path, "eth1h.csv"))

#df = df.iloc[-500:].reset_index(drop=True)

# Test the corrected functions
high_points = find_highs(df, "Close")
low_points = find_lows(df, "Close")

# %%
# Load the data from the provided CSV file

# Test the refined function
high_points = refine_highs(df, "Close", 2)
high_points
# Out:
# [44, 424]

# %%
# Testing the refined function for lows
low_points = refine_lows(df, "Close", 2)
low_points
# Out:
# [24, 293, 493]

# %%
def insert_missing_points(df, high_points, low_points, column_name_high, column_name_low):
    """
    Inserts missing low points between high points and vice-versa.

    Parameters:
    - df: DataFrame containing the data
    - high_points: List of high point indices
    - low_points: List of low point indices
    - column_name_high: Name of the column containing high values
    - column_name_low: Name of the column containing low values

    Returns:
    - updated_high_points: Updated list of high point indices
    - updated_low_points: Updated list of low point indices
    """
    
    updated_high_points = high_points.copy()
    updated_low_points = low_points.copy()

    # Check for missing low points between consecutive high points
    for i in range(len(high_points) - 1):
        segment = df.iloc[high_points[i]:high_points[i+1]+1]
        if not any(segment.index.isin(low_points)):
            min_idx = segment[column_name_low].idxmin()
            updated_low_points.append(min_idx)

    # Check for missing high points between consecutive low points
    for i in range(len(low_points) - 1):
        segment = df.iloc[low_points[i]:low_points[i+1]+1]
        if not any(segment.index.isin(high_points)):
            max_idx = segment[column_name_high].idxmax()
            updated_high_points.append(max_idx)

    # Sort the updated points
    updated_high_points.sort()
    updated_low_points.sort()

    return updated_high_points, updated_low_points

high_points, low_points = insert_missing_points(df, high_points, low_points, "Close", "Close")

# %%
import matplotlib.pyplot as plt

def plot_with_highs_lows(df, column_name, high_indices, low_indices, 
                         title="Plot", xlabel="Index", ylabel="Value"):
    """
    Plots the specified column of the DataFrame and marks the high and low indices with different colors.

    Parameters:
    - df: DataFrame containing the data
    - column_name: Name of the column to be plotted
    - high_indices: List of high indices to be marked
    - low_indices: List of low indices to be marked
    - title: Title of the plot
    - xlabel: Label for the x-axis
    - ylabel: Label for the y-axis
    """
    
    plt.figure(figsize=(12, 6))
    
    # Plotting the specified column
    plt.plot(df[column_name], label=column_name, color='blue', alpha=0.7)
    
    # Marking the high indices
    plt.scatter(high_indices, df[column_name].iloc[high_indices], color='green', marker='^', label='High Points')
    
    # Marking the low indices
    plt.scatter(low_indices, df[column_name].iloc[low_indices], color='red', marker='v', label='Low Points')
    
    # Adding labels, title, legend and grid
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()
    plt.grid(True)
    
    plt.show()

# Using the updated plotting API to plot the Close values with the refined high and low points
plot_with_highs_lows(df, "Close", high_points, low_points, title="Close Values with High and Low Points")

# %%
// list of contextes / lookbacks to aggreate features over [25, 250, 1000]

for each row:
    for each lookback length: 
        // take lookback length
        // min max normalize of close
        // get last 4 highs&lows
        // get segmentation
        // extract features for each segment and make it feature of row
        
extract features trendy timeseries
# Out:
#   File "<ipython-input-105-73ea8ad95530>", line 1
#     // list of contextes / lookbacks to aggreate features over
#     ^
# SyntaxError: invalid syntax

# %%
## single features

def extract_segment_features(df, column_name="Close"):
    """Extract features for a given segment of data.
    
    Parameters:
    - df: Segment of the DataFrame
    - column_name: Name of the column to extract features from
    
    Returns:
    - feature: Mean of the percentage change of the Close prices for the segment
    """
    
    return df[column_name].pct_change().mean()

def process_row(df, idx, lookback, column_name="Close"):
    """Process a single row to extract features based on lookback.
    
    Parameters:
    - df: DataFrame containing the data
    - idx: Index of the row to process
    - lookback: Length of the lookback period
    - column_name: Name of the column to extract features from
    
    Returns:
    - features: Extracted features for the row
    """
    
    # Get the lookback window for the current index
    start_idx = max(0, idx - lookback)
    window_df = df.iloc[start_idx:idx+1].copy()
    
    # Reset the indices of the window dataframe
    window_df.reset_index(drop=True, inplace=True)
    
    # Normalize the Close prices within the window
    min_val = window_df[column_name].min()
    max_val = window_df[column_name].max()
    window_df["Normalized"] = (window_df[column_name] - min_val) / (max_val - min_val)
    
    # Find refined highs and lows
    highs = refine_highs(window_df, "Normalized", 4)
    lows = refine_lows(window_df, "Normalized", 4)
    
    # Combine and sort highs and lows to create segments
    extremas = sorted(highs + lows)[-4:]  # Only consider the last 4 extremas
    print("EXTREMA:", extremas)
    # Extract features for each segment
    features = []
    for i in range(len(extremas) - 1):
        segment = window_df.iloc[extremas[i]:extremas[i+1]]
        feature = extract_segment_features(segment)
        features.append(feature)
    
    # Include the segment from the last extrema to the end of the lookback window
    if extremas:
        segment = window_df.iloc[extremas[-1]:]
        feature = extract_segment_features(segment)
        features.append(feature)
    
    # If no segments were found, return NaN
    if not features:
        return [None] * 4
    
    # If less than 4 segments were found, fill the remaining with NaN
    while len(features) < 4:
        features.append(None)
    
    return features

def extract_features_from_df(df, lookbacks=[25, 250, 1000], column_name="Close"):
    """Extract features from the DataFrame for each lookback period.
    
    Parameters:
    - df: DataFrame containing the data
    - lookbacks: List of lookback periods
    - column_name: Name of the column to extract features from
    
    Returns:
    - df: DataFrame augmented with extracted features
    """
    print("lookbacks", lookbacks)
    for i in range(len(df)-1):
        row_features = {}

        for lookback in lookbacks:
            if i <= lookback:
                continue
            print("lookback", lookback)
            df_ = df.iloc[i-lookback:i]
            features = process_row(df, i, lookback, column_name="Close")
            print(len(features), "fts")
            #df[f"Feature_{lookback}_1"], df[f"Feature_{lookback}_2"], df[f"Feature_{lookback}_3"], df[f"Feature_{lookback}_4"] = zip(*features)
            for j, feature in enumerate(features, 1):
                row_features[f"Feature_{lookback}_{j}"] = feature
                

        features_data.append(row_features)

# Convert the placeholder to a DataFrame
    features_df = pd.DataFrame(features_data)

    # Concatenate the original DataFrame with the features DataFrame
    features_df = pd.concat([df, features_df], axis=1)

    # Display the augmented DataFrame with the extracted features

    return features_df

truncated_df = df.iloc[-500:].reset_index(drop=True)

# Re-run the feature extraction process
augmented_df = extract_features_from_df(truncated_df)

# Display the augmented DataFrame with the extracted features
augmented_df.head()
# Out:
# lookbacks [25, 250, 1000]
# lookback 25
# EXTREMA: [9, 14, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [8, 13, 22, 24]
# 4 fts
# lookback 25
# EXTREMA: [7, 12, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [6, 11, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [5, 10, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [4, 9, 18, 25]
# 4 fts
# lookback 25
# EXTREMA: [8, 17, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [7, 16, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [6, 15, 23, 24]
# 4 fts
# lookback 25
# EXTREMA: [5, 14, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [4, 13, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [3, 12, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 11, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [1, 10, 18, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 9, 17, 24]
# 4 fts
# lookback 25
# EXTREMA: [2, 8, 16, 23]
# 4 fts
# lookback 25
# EXTREMA: [1, 7, 15, 22]
# 4 fts
# lookback 25
# EXTREMA: [15, 19, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [14, 18, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [13, 17, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [12, 16, 18, 23]
# 4 fts
# lookback 25
# EXTREMA: [11, 15, 17, 22]
# 4 fts
# lookback 25
# EXTREMA: [10, 14, 16, 21]
# 4 fts
# lookback 25
# EXTREMA: [9, 13, 15, 20]
# 4 fts
# lookback 25
# EXTREMA: [8, 12, 14, 19]
# 4 fts
# lookback 25
# EXTREMA: [7, 11, 13, 18]
# 4 fts
# lookback 25
# EXTREMA: [10, 12, 17, 25]
# 4 fts
# lookback 25
# EXTREMA: [9, 11, 16, 24]
# 4 fts
# lookback 25
# EXTREMA: [10, 15, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [14, 22, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [13, 21, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [0, 12, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 11, 23, 24]
# 4 fts
# lookback 25
# EXTREMA: [0, 10, 22, 23]
# 4 fts
# lookback 25
# EXTREMA: [0, 9, 21, 22]
# 4 fts
# lookback 25
# EXTREMA: [0, 8, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 7, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [0, 6, 19, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 5, 18, 24]
# 4 fts
# lookback 25
# EXTREMA: [1, 4, 17, 23]
# 4 fts
# lookback 25
# EXTREMA: [0, 3, 16, 22]
# 4 fts
# lookback 25
# EXTREMA: [2, 15, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [20, 23, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [19, 22, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [18, 21, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [17, 20, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [16, 19, 20, 24]
# 4 fts
# lookback 25
# EXTREMA: [9, 15, 19, 25]
# 4 fts
# lookback 25
# EXTREMA: [14, 18, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [13, 17, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [12, 16, 22, 24]
# 4 fts
# lookback 25
# EXTREMA: [11, 15, 21, 23]
# 4 fts
# lookback 25
# EXTREMA: [10, 14, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [9, 13, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [8, 12, 18, 23]
# 4 fts
# lookback 25
# EXTREMA: [11, 17, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [10, 16, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [9, 15, 20, 24]
# 4 fts
# lookback 25
# EXTREMA: [8, 14, 19, 23]
# 4 fts
# lookback 25
# EXTREMA: [7, 13, 18, 25]
# 4 fts
# lookback 25
# EXTREMA: [12, 17, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [11, 16, 23, 24]
# 4 fts
# lookback 25
# EXTREMA: [10, 15, 22, 23]
# 4 fts
# lookback 25
# EXTREMA: [9, 14, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [8, 13, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [7, 12, 20, 24]
# 4 fts
# lookback 25
# EXTREMA: [6, 11, 19, 23]
# 4 fts
# lookback 25
# EXTREMA: [5, 10, 18, 22]
# 4 fts
# lookback 25
# EXTREMA: [4, 9, 17, 21]
# 4 fts
# lookback 25
# EXTREMA: [3, 8, 16, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 7, 15, 24]
# 4 fts
# lookback 25
# EXTREMA: [1, 6, 14, 23]
# 4 fts
# lookback 25
# EXTREMA: [0, 5, 13, 22]
# 4 fts
# lookback 25
# EXTREMA: [0, 4, 12, 21]
# 4 fts
# lookback 25
# EXTREMA: [15, 20, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [14, 19, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [18, 22, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [17, 21, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [20, 23, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [19, 22, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [18, 21, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [20, 23, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [19, 22, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [18, 21, 22, 24]
# 4 fts
# lookback 25
# EXTREMA: [1, 10, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [0, 9, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [5, 8, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [4, 7, 18, 23]
# 4 fts
# lookback 25
# EXTREMA: [3, 6, 17, 22]
# 4 fts
# lookback 25
# EXTREMA: [2, 5, 16, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 4, 15, 25]
# 4 fts
# lookback 25
# EXTREMA: [0, 3, 14, 24]
# 4 fts
# lookback 25
# EXTREMA: [0, 2, 13, 23]
# 4 fts
# lookback 25
# EXTREMA: [0, 1, 12, 22]
# 4 fts
# lookback 25
# EXTREMA: [14, 19, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [13, 18, 20, 24]
# 4 fts
# lookback 25
# EXTREMA: [17, 19, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [18, 22, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [17, 21, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [16, 20, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [15, 19, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [18, 20, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [17, 19, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [16, 18, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [15, 17, 21, 24]
# 4 fts
# lookback 25
# EXTREMA: [14, 16, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [13, 15, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [12, 14, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [11, 13, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [12, 19, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [11, 18, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 4, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 3, 21, 24]
# 4 fts
# lookback 25
# EXTREMA: [0, 2, 20, 23]
# 4 fts
# lookback 25
# EXTREMA: [1, 5, 19, 22]
# 4 fts
# lookback 25
# EXTREMA: [0, 4, 18, 21]
# 4 fts
# lookback 25
# EXTREMA: [3, 17, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 16, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [1, 15, 18, 23]
# 4 fts
# lookback 25
# EXTREMA: [0, 14, 17, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 13, 16, 25]
# 4 fts
# lookback 25
# EXTREMA: [0, 12, 15, 25]
# 4 fts
# lookback 25
# EXTREMA: [0, 11, 14, 24]
# 4 fts
# lookback 25
# EXTREMA: [0, 10, 13, 25]
# 4 fts
# lookback 25
# EXTREMA: [9, 12, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [8, 11, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [7, 10, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [6, 9, 22, 24]
# 4 fts
# lookback 25
# EXTREMA: [5, 8, 21, 23]
# 4 fts
# lookback 25
# EXTREMA: [4, 7, 20, 22]
# 4 fts
# lookback 25
# EXTREMA: [3, 6, 19, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 5, 18, 24]
# 4 fts
# lookback 25
# EXTREMA: [4, 17, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [3, 16, 22, 24]
# 4 fts
# lookback 25
# EXTREMA: [2, 15, 21, 23]
# 4 fts
# lookback 25
# EXTREMA: [1, 14, 20, 22]
# 4 fts
# lookback 25
# EXTREMA: [15, 19, 21, 22]
# 4 fts
# lookback 25
# EXTREMA: [18, 20, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [19, 20, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [19, 23, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [18, 22, 23, 24]
# 4 fts
# lookback 25
# EXTREMA: [17, 21, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [20, 22, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [19, 21, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [11, 13, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [10, 12, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [9, 11, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [8, 10, 21, 24]
# 4 fts
# lookback 25
# EXTREMA: [7, 9, 20, 23]
# 4 fts
# lookback 25
# EXTREMA: [6, 8, 19, 22]
# 4 fts
# lookback 25
# EXTREMA: [7, 18, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [17, 20, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [16, 19, 24, 25]
# 4 fts
# lookback 25
# EXTREMA: [15, 18, 23, 24]
# 4 fts
# lookback 25
# EXTREMA: [14, 17, 22, 23]
# 4 fts
# lookback 25
# EXTREMA: [16, 21, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [15, 20, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [14, 19, 20, 24]
# 4 fts
# lookback 25
# EXTREMA: [18, 19, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [17, 18, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [16, 17, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [15, 16, 20, 24]
# 4 fts
# lookback 25
# EXTREMA: [14, 15, 19, 23]
# 4 fts
# lookback 25
# EXTREMA: [13, 14, 18, 22]
# 4 fts
# lookback 25
# EXTREMA: [12, 13, 17, 21]
# 4 fts
# lookback 25
# EXTREMA: [11, 12, 16, 20]
# 4 fts
# lookback 25
# EXTREMA: [10, 11, 15, 19]
# 4 fts
# lookback 25
# EXTREMA: [10, 14, 18, 25]
# 4 fts
# lookback 25
# EXTREMA: [9, 13, 17, 24]
# 4 fts
# lookback 25
# EXTREMA: [8, 12, 16, 25]
# 4 fts
# lookback 25
# EXTREMA: [7, 11, 15, 25]
# 4 fts
# lookback 25
# EXTREMA: [6, 10, 14, 25]
# 4 fts
# lookback 25
# EXTREMA: [5, 9, 13, 25]
# 4 fts
# lookback 25
# EXTREMA: [4, 8, 12, 25]
# 4 fts
# lookback 25
# EXTREMA: [3, 7, 11, 24]
# 4 fts
# lookback 25
# EXTREMA: [2, 6, 10, 23]
# 4 fts
# lookback 25
# EXTREMA: [5, 9, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [4, 8, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [3, 7, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 6, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [1, 5, 18, 23]
# 4 fts
# lookback 25
# EXTREMA: [0, 4, 17, 22]
# 4 fts
# lookback 25
# EXTREMA: [0, 3, 16, 21]
# 4 fts
# lookback 25
# EXTREMA: [2, 15, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 14, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [0, 13, 18, 23]
# 4 fts
# lookback 25
# EXTREMA: [0, 12, 17, 22]
# 4 fts
# lookback 25
# EXTREMA: [0, 11, 16, 21]
# 4 fts
# lookback 25
# EXTREMA: [0, 10, 15, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 9, 14, 24]
# 4 fts
# lookback 25
# EXTREMA: [0, 8, 13, 23]
# 4 fts
# lookback 25
# EXTREMA: [0, 7, 12, 22]
# 4 fts
# lookback 25
# EXTREMA: [1, 6, 11, 21]
# 4 fts
# lookback 25
# EXTREMA: [5, 10, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [4, 9, 19, 24]
# 4 fts
# lookback 25
# EXTREMA: [3, 8, 18, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 7, 17, 24]
# 4 fts
# lookback 25
# EXTREMA: [1, 6, 16, 23]
# 4 fts
# lookback 25
# EXTREMA: [5, 15, 22, 25]
# 4 fts
# lookback 25
# EXTREMA: [4, 14, 21, 24]
# 4 fts
# lookback 25
# EXTREMA: [3, 13, 20, 23]
# 4 fts
# lookback 25
# EXTREMA: [2, 12, 19, 22]
# 4 fts
# lookback 25
# EXTREMA: [1, 11, 18, 21]
# 4 fts
# lookback 25
# EXTREMA: [10, 17, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [9, 16, 19, 25]
# 4 fts
# lookback 25
# EXTREMA: [8, 15, 18, 24]
# 4 fts
# lookback 25
# EXTREMA: [7, 14, 17, 23]
# 4 fts
# lookback 25
# EXTREMA: [6, 13, 16, 22]
# 4 fts
# lookback 25
# EXTREMA: [5, 12, 15, 21]
# 4 fts
# lookback 25
# EXTREMA: [4, 11, 14, 20]
# 4 fts
# lookback 25
# EXTREMA: [3, 10, 13, 19]
# 4 fts
# lookback 25
# EXTREMA: [9, 12, 18, 25]
# 4 fts
# lookback 25
# EXTREMA: [8, 11, 17, 24]
# 4 fts
# lookback 25
# EXTREMA: [7, 10, 16, 23]
# 4 fts
# lookback 25
# EXTREMA: [6, 9, 15, 22]
# 4 fts
# lookback 25
# EXTREMA: [8, 14, 21, 25]
# 4 fts
# lookback 25
# EXTREMA: [7, 13, 20, 25]
# 4 fts
# lookback 25
# EXTREMA: [6, 12, 19, 25]
# 4 fts
# lookback 25
# EXTREMA: [5, 11, 18, 24]
# 4 fts
# lookback 25
# EXTREMA: [4, 10, 17, 25]
# 4 fts
# lookback 25
# EXTREMA: [3, 9, 16, 25]
# 4 fts
# lookback 25
# EXTREMA: [2, 8, 15, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 7, 14, 25]
# 4 fts
# lookback 25
# EXTREMA: [1, 6, 13, 24]
# 4 fts
# lookback 25
# EXTREMA: [15, 19, 23, 25]
# 4 fts
# lookback 25
# EXTREMA: [14, 18, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [133, 198, 203, 247]
# 4 fts
# lookback 25
# EXTREMA: [13, 17, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [132, 197, 202, 246]
# 4 fts
# lookback 25
# EXTREMA: [12, 16, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [131, 196, 201, 250]
# 4 fts
# lookback 25
# EXTREMA: [11, 15, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [130, 195, 200, 250]
# 4 fts
# lookback 25
# EXTREMA: [14, 22, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [129, 194, 199, 249]
# 4 fts
# lookback 25
# EXTREMA: [13, 21, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [128, 193, 198, 248]
# 4 fts
# lookback 25
# EXTREMA: [12, 20, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [127, 192, 197, 247]
# 4 fts
# lookback 25
# EXTREMA: [11, 19, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [126, 191, 196, 246]
# 4 fts
# lookback 25
# EXTREMA: [10, 18, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [125, 190, 195, 250]
# 4 fts
# lookback 25
# EXTREMA: [9, 17, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [124, 189, 194, 250]
# 4 fts
# lookback 25
# EXTREMA: [16, 20, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [123, 188, 193, 249]
# 4 fts
# lookback 25
# EXTREMA: [15, 19, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [122, 187, 192, 248]
# 4 fts
# lookback 25
# EXTREMA: [18, 22, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [121, 186, 191, 247]
# 4 fts
# lookback 25
# EXTREMA: [15, 21, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [120, 185, 190, 246]
# 4 fts
# lookback 25
# EXTREMA: [14, 20, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [119, 184, 189, 245]
# 4 fts
# lookback 25
# EXTREMA: [19, 22, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [118, 183, 188, 244]
# 4 fts
# lookback 25
# EXTREMA: [18, 21, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [117, 182, 187, 243]
# 4 fts
# lookback 25
# EXTREMA: [17, 20, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [116, 181, 186, 242]
# 4 fts
# lookback 25
# EXTREMA: [19, 22, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [115, 180, 185, 241]
# 4 fts
# lookback 25
# EXTREMA: [18, 21, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [114, 179, 184, 240]
# 4 fts
# lookback 25
# EXTREMA: [17, 20, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [113, 178, 183, 239]
# 4 fts
# lookback 25
# EXTREMA: [16, 19, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [112, 177, 182, 238]
# 4 fts
# lookback 25
# EXTREMA: [4, 12, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [111, 176, 181, 237]
# 4 fts
# lookback 25
# EXTREMA: [3, 11, 19, 24]
# 4 fts
# lookback 250
# EXTREMA: [110, 175, 180, 236]
# 4 fts
# lookback 25
# EXTREMA: [2, 10, 18, 23]
# 4 fts
# lookback 250
# EXTREMA: [109, 174, 179, 235]
# 4 fts
# lookback 25
# EXTREMA: [9, 17, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [108, 173, 178, 234]
# 4 fts
# lookback 25
# EXTREMA: [8, 16, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [107, 172, 177, 233]
# 4 fts
# lookback 25
# EXTREMA: [7, 15, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [171, 176, 232, 250]
# 4 fts
# lookback 25
# EXTREMA: [6, 14, 19, 24]
# 4 fts
# lookback 250
# EXTREMA: [170, 175, 231, 249]
# 4 fts
# lookback 25
# EXTREMA: [5, 13, 18, 23]
# 4 fts
# lookback 250
# EXTREMA: [169, 174, 230, 248]
# 4 fts
# lookback 25
# EXTREMA: [12, 17, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [168, 173, 229, 247]
# 4 fts
# lookback 25
# EXTREMA: [11, 16, 21, 24]
# 4 fts
# lookback 250
# EXTREMA: [167, 172, 228, 246]
# 4 fts
# lookback 25
# EXTREMA: [10, 15, 20, 23]
# 4 fts
# lookback 250
# EXTREMA: [166, 171, 227, 245]
# 4 fts
# lookback 25
# EXTREMA: [9, 14, 19, 22]
# 4 fts
# lookback 250
# EXTREMA: [165, 170, 226, 244]
# 4 fts
# lookback 25
# EXTREMA: [8, 13, 18, 25]
# 4 fts
# lookback 250
# EXTREMA: [164, 169, 225, 243]
# 4 fts
# lookback 25
# EXTREMA: [7, 12, 17, 25]
# 4 fts
# lookback 250
# EXTREMA: [163, 168, 224, 242]
# 4 fts
# lookback 25
# EXTREMA: [6, 11, 16, 25]
# 4 fts
# lookback 250
# EXTREMA: [97, 162, 223, 241]
# 4 fts
# lookback 25
# EXTREMA: [5, 10, 15, 24]
# 4 fts
# lookback 250
# EXTREMA: [96, 161, 222, 240]
# 4 fts
# lookback 25
# EXTREMA: [4, 9, 14, 23]
# 4 fts
# lookback 250
# EXTREMA: [95, 160, 221, 239]
# 4 fts
# lookback 25
# EXTREMA: [3, 8, 13, 22]
# 4 fts
# lookback 250
# EXTREMA: [94, 159, 220, 238]
# 4 fts
# lookback 25
# EXTREMA: [7, 12, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [93, 158, 219, 237]
# 4 fts
# lookback 25
# EXTREMA: [6, 11, 20, 24]
# 4 fts
# lookback 250
# EXTREMA: [92, 157, 218, 236]
# 4 fts
# lookback 25
# EXTREMA: [10, 19, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [91, 156, 235, 250]
# 4 fts
# lookback 25
# EXTREMA: [9, 18, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [90, 155, 234, 249]
# 4 fts
# lookback 25
# EXTREMA: [8, 17, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [89, 154, 233, 248]
# 4 fts
# lookback 25
# EXTREMA: [7, 16, 20, 22]
# 4 fts
# lookback 250
# EXTREMA: [88, 153, 232, 247]
# 4 fts
# lookback 25
# EXTREMA: [6, 15, 19, 21]
# 4 fts
# lookback 250
# EXTREMA: [87, 152, 231, 246]
# 4 fts
# lookback 25
# EXTREMA: [5, 14, 18, 20]
# 4 fts
# lookback 250
# EXTREMA: [86, 151, 230, 245]
# 4 fts
# lookback 25
# EXTREMA: [4, 13, 17, 19]
# 4 fts
# lookback 250
# EXTREMA: [85, 150, 229, 244]
# 4 fts
# lookback 25
# EXTREMA: [3, 12, 16, 18]
# 4 fts
# lookback 250
# EXTREMA: [84, 149, 228, 243]
# 4 fts
# lookback 25
# EXTREMA: [2, 11, 15, 17]
# 4 fts
# lookback 250
# EXTREMA: [83, 148, 227, 242]
# 4 fts
# lookback 25
# EXTREMA: [10, 14, 16, 25]
# 4 fts
# lookback 250
# EXTREMA: [82, 147, 226, 241]
# 4 fts
# lookback 25
# EXTREMA: [9, 13, 15, 24]
# 4 fts
# lookback 250
# EXTREMA: [81, 146, 225, 240]
# 4 fts
# lookback 25
# EXTREMA: [8, 12, 14, 25]
# 4 fts
# lookback 250
# EXTREMA: [80, 145, 224, 239]
# 4 fts
# lookback 25
# EXTREMA: [7, 11, 13, 24]
# 4 fts
# lookback 250
# EXTREMA: [79, 144, 223, 238]
# 4 fts
# lookback 25
# EXTREMA: [10, 12, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [78, 143, 222, 237]
# 4 fts
# lookback 25
# EXTREMA: [9, 11, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [77, 142, 221, 236]
# 4 fts
# lookback 25
# EXTREMA: [8, 10, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [76, 141, 220, 235]
# 4 fts
# lookback 25
# EXTREMA: [7, 9, 20, 22]
# 4 fts
# lookback 250
# EXTREMA: [75, 140, 219, 234]
# 4 fts
# lookback 25
# EXTREMA: [8, 19, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [74, 139, 218, 233]
# 4 fts
# lookback 25
# EXTREMA: [7, 18, 20, 24]
# 4 fts
# lookback 250
# EXTREMA: [73, 138, 217, 232]
# 4 fts
# lookback 25
# EXTREMA: [17, 19, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [72, 137, 216, 231]
# 4 fts
# lookback 25
# EXTREMA: [16, 18, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [71, 136, 215, 230]
# 4 fts
# lookback 25
# EXTREMA: [15, 17, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [70, 135, 214, 229]
# 4 fts
# lookback 25
# EXTREMA: [14, 16, 20, 22]
# 4 fts
# lookback 250
# EXTREMA: [69, 134, 213, 228]
# 4 fts
# lookback 25
# EXTREMA: [15, 19, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [68, 133, 212, 227]
# 4 fts
# lookback 25
# EXTREMA: [14, 18, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [137, 193, 211, 226]
# 4 fts
# lookback 25
# EXTREMA: [13, 17, 19, 24]
# 4 fts
# lookback 250
# EXTREMA: [136, 192, 210, 225]
# 4 fts
# lookback 25
# EXTREMA: [12, 16, 18, 23]
# 4 fts
# lookback 250
# EXTREMA: [135, 191, 209, 224]
# 4 fts
# lookback 25
# EXTREMA: [11, 15, 17, 22]
# 4 fts
# lookback 250
# EXTREMA: [134, 190, 208, 223]
# 4 fts
# lookback 25
# EXTREMA: [10, 14, 16, 25]
# 4 fts
# lookback 250
# EXTREMA: [133, 189, 207, 222]
# 4 fts
# lookback 25
# EXTREMA: [9, 13, 15, 24]
# 4 fts
# lookback 250
# EXTREMA: [132, 188, 206, 221]
# 4 fts
# lookback 25
# EXTREMA: [8, 12, 14, 23]
# 4 fts
# lookback 250
# EXTREMA: [131, 187, 205, 220]
# 4 fts
# lookback 25
# EXTREMA: [7, 11, 13, 22]
# 4 fts
# lookback 250
# EXTREMA: [130, 186, 204, 219]
# 4 fts
# lookback 25
# EXTREMA: [10, 12, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [129, 185, 203, 218]
# 4 fts
# lookback 25
# EXTREMA: [9, 11, 20, 24]
# 4 fts
# lookback 250
# EXTREMA: [128, 184, 202, 217]
# 4 fts
# lookback 25
# EXTREMA: [8, 10, 19, 23]
# 4 fts
# lookback 250
# EXTREMA: [127, 183, 201, 216]
# 4 fts
# lookback 25
# EXTREMA: [7, 9, 18, 25]
# 4 fts
# lookback 250
# EXTREMA: [126, 182, 200, 215]
# 4 fts
# lookback 25
# EXTREMA: [6, 8, 17, 24]
# 4 fts
# lookback 250
# EXTREMA: [125, 181, 199, 214]
# 4 fts
# lookback 25
# EXTREMA: [5, 7, 16, 23]
# 4 fts
# lookback 250
# EXTREMA: [124, 180, 198, 213]
# 4 fts
# lookback 25
# EXTREMA: [4, 6, 15, 22]
# 4 fts
# lookback 250
# EXTREMA: [123, 179, 197, 212]
# 4 fts
# lookback 25
# EXTREMA: [5, 14, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [122, 178, 196, 211]
# 4 fts
# lookback 25
# EXTREMA: [4, 13, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [121, 177, 195, 210]
# 4 fts
# lookback 25
# EXTREMA: [3, 12, 19, 24]
# 4 fts
# lookback 250
# EXTREMA: [120, 176, 194, 209]
# 4 fts
# lookback 25
# EXTREMA: [2, 11, 18, 23]
# 4 fts
# lookback 250
# EXTREMA: [119, 175, 193, 208]
# 4 fts
# lookback 25
# EXTREMA: [1, 10, 17, 22]
# 4 fts
# lookback 250
# EXTREMA: [118, 174, 192, 207]
# 4 fts
# lookback 25
# EXTREMA: [0, 9, 16, 21]
# 4 fts
# lookback 250
# EXTREMA: [117, 173, 191, 206]
# 4 fts
# lookback 25
# EXTREMA: [8, 15, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [116, 172, 190, 205]
# 4 fts
# lookback 25
# EXTREMA: [7, 14, 19, 25]
# 4 fts
# lookback 250
# EXTREMA: [45, 110, 189, 204]
# 4 fts
# lookback 25
# EXTREMA: [6, 13, 18, 24]
# 4 fts
# lookback 250
# EXTREMA: [44, 109, 188, 203]
# 4 fts
# lookback 25
# EXTREMA: [5, 12, 17, 25]
# 4 fts
# lookback 250
# EXTREMA: [43, 108, 187, 202]
# 4 fts
# lookback 25
# EXTREMA: [4, 11, 16, 24]
# 4 fts
# lookback 250
# EXTREMA: [42, 107, 186, 201]
# 4 fts
# lookback 25
# EXTREMA: [3, 10, 15, 23]
# 4 fts
# lookback 250
# EXTREMA: [41, 106, 185, 200]
# 4 fts
# lookback 25
# EXTREMA: [9, 14, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [40, 105, 184, 199]
# 4 fts
# lookback 25
# EXTREMA: [8, 13, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [39, 104, 183, 198]
# 4 fts
# lookback 25
# EXTREMA: [7, 12, 20, 24]
# 4 fts
# lookback 250
# EXTREMA: [38, 103, 182, 197]
# 4 fts
# lookback 25
# EXTREMA: [6, 11, 19, 25]
# 4 fts
# lookback 250
# EXTREMA: [37, 102, 181, 196]
# 4 fts
# lookback 25
# EXTREMA: [5, 10, 18, 24]
# 4 fts
# lookback 250
# EXTREMA: [36, 101, 180, 195]
# 4 fts
# lookback 25
# EXTREMA: [9, 17, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [35, 100, 179, 194]
# 4 fts
# lookback 25
# EXTREMA: [8, 16, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [99, 178, 193, 250]
# 4 fts
# lookback 25
# EXTREMA: [7, 15, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [98, 177, 192, 250]
# 4 fts
# lookback 25
# EXTREMA: [6, 14, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [97, 176, 191, 250]
# 4 fts
# lookback 25
# EXTREMA: [5, 13, 21, 24]
# 4 fts
# lookback 250
# EXTREMA: [96, 175, 190, 249]
# 4 fts
# lookback 25
# EXTREMA: [4, 12, 20, 23]
# 4 fts
# lookback 250
# EXTREMA: [95, 174, 189, 248]
# 4 fts
# lookback 25
# EXTREMA: [4, 11, 19, 22]
# 4 fts
# lookback 250
# EXTREMA: [94, 173, 188, 247]
# 4 fts
# lookback 25
# EXTREMA: [10, 18, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [93, 172, 187, 246]
# 4 fts
# lookback 25
# EXTREMA: [17, 20, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [92, 171, 186, 245]
# 4 fts
# lookback 25
# EXTREMA: [16, 19, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [91, 170, 185, 244]
# 4 fts
# lookback 25
# EXTREMA: [15, 18, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [90, 169, 184, 243]
# 4 fts
# lookback 25
# EXTREMA: [14, 17, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [89, 168, 183, 250]
# 4 fts
# lookback 25
# EXTREMA: [13, 16, 20, 24]
# 4 fts
# lookback 250
# EXTREMA: [88, 167, 182, 249]
# 4 fts
# lookback 25
# EXTREMA: [15, 19, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [87, 166, 181, 248]
# 4 fts
# lookback 25
# EXTREMA: [14, 18, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [86, 165, 180, 247]
# 4 fts
# lookback 25
# EXTREMA: [13, 17, 21, 24]
# 4 fts
# lookback 250
# EXTREMA: [85, 164, 179, 246]
# 4 fts
# lookback 25
# EXTREMA: [12, 16, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [84, 163, 178, 250]
# 4 fts
# lookback 25
# EXTREMA: [11, 15, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [83, 162, 177, 249]
# 4 fts
# lookback 25
# EXTREMA: [10, 14, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [82, 161, 176, 248]
# 4 fts
# lookback 25
# EXTREMA: [9, 13, 20, 22]
# 4 fts
# lookback 250
# EXTREMA: [81, 160, 175, 247]
# 4 fts
# lookback 25
# EXTREMA: [12, 19, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [80, 159, 174, 246]
# 4 fts
# lookback 25
# EXTREMA: [11, 18, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [79, 158, 173, 245]
# 4 fts
# lookback 25
# EXTREMA: [10, 17, 19, 25]
# 4 fts
# lookback 250
# EXTREMA: [78, 157, 172, 244]
# 4 fts
# lookback 25
# EXTREMA: [9, 16, 18, 25]
# 4 fts
# lookback 250
# EXTREMA: [77, 156, 171, 243]
# 4 fts
# lookback 25
# EXTREMA: [8, 15, 17, 25]
# 4 fts
# lookback 250
# EXTREMA: [76, 155, 170, 242]
# 4 fts
# lookback 25
# EXTREMA: [7, 14, 16, 25]
# 4 fts
# lookback 250
# EXTREMA: [75, 154, 169, 241]
# 4 fts
# lookback 25
# EXTREMA: [6, 13, 15, 24]
# 4 fts
# lookback 250
# EXTREMA: [74, 153, 168, 240]
# 4 fts
# lookback 25
# EXTREMA: [5, 12, 14, 25]
# 4 fts
# lookback 250
# EXTREMA: [73, 152, 167, 239]
# 4 fts
# lookback 25
# EXTREMA: [4, 11, 13, 24]
# 4 fts
# lookback 250
# EXTREMA: [72, 151, 166, 238]
# 4 fts
# lookback 25
# EXTREMA: [15, 22, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [71, 150, 165, 237]
# 4 fts
# lookback 25
# EXTREMA: [9, 11, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [70, 149, 164, 236]
# 4 fts
# lookback 25
# EXTREMA: [8, 10, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [69, 148, 163, 235]
# 4 fts
# lookback 25
# EXTREMA: [7, 9, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [68, 147, 162, 234]
# 4 fts
# lookback 25
# EXTREMA: [6, 8, 21, 24]
# 4 fts
# lookback 250
# EXTREMA: [67, 146, 161, 233]
# 4 fts
# lookback 25
# EXTREMA: [5, 7, 20, 23]
# 4 fts
# lookback 250
# EXTREMA: [66, 145, 160, 232]
# 4 fts
# lookback 25
# EXTREMA: [4, 6, 19, 25]
# 4 fts
# lookback 250
# EXTREMA: [65, 144, 159, 231]
# 4 fts
# lookback 25
# EXTREMA: [5, 18, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [158, 206, 230, 243]
# 4 fts
# lookback 25
# EXTREMA: [4, 17, 23, 24]
# 4 fts
# lookback 250
# EXTREMA: [157, 205, 229, 242]
# 4 fts
# lookback 25
# EXTREMA: [3, 16, 22, 23]
# 4 fts
# lookback 250
# EXTREMA: [156, 204, 228, 241]
# 4 fts
# lookback 25
# EXTREMA: [15, 21, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [155, 203, 227, 240]
# 4 fts
# lookback 25
# EXTREMA: [14, 20, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [154, 202, 226, 239]
# 4 fts
# lookback 25
# EXTREMA: [13, 19, 20, 24]
# 4 fts
# lookback 250
# EXTREMA: [153, 201, 225, 238]
# 4 fts
# lookback 25
# EXTREMA: [12, 18, 19, 23]
# 4 fts
# lookback 250
# EXTREMA: [152, 200, 224, 237]
# 4 fts
# lookback 25
# EXTREMA: [11, 17, 18, 25]
# 4 fts
# lookback 250
# EXTREMA: [151, 199, 223, 236]
# 4 fts
# lookback 25
# EXTREMA: [10, 16, 17, 24]
# 4 fts
# lookback 250
# EXTREMA: [150, 198, 222, 235]
# 4 fts
# lookback 25
# EXTREMA: [9, 15, 16, 25]
# 4 fts
# lookback 250
# EXTREMA: [149, 197, 221, 234]
# 4 fts
# lookback 25
# EXTREMA: [8, 14, 15, 24]
# 4 fts
# lookback 250
# EXTREMA: [148, 196, 220, 233]
# 4 fts
# lookback 25
# EXTREMA: [7, 13, 14, 23]
# 4 fts
# lookback 250
# EXTREMA: [147, 195, 219, 232]
# 4 fts
# lookback 25
# EXTREMA: [12, 13, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [146, 194, 218, 231]
# 4 fts
# lookback 25
# EXTREMA: [11, 12, 21, 24]
# 4 fts
# lookback 250
# EXTREMA: [145, 193, 217, 230]
# 4 fts
# lookback 25
# EXTREMA: [10, 11, 20, 23]
# 4 fts
# lookback 250
# EXTREMA: [144, 192, 216, 229]
# 4 fts
# lookback 25
# EXTREMA: [10, 19, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [143, 191, 215, 228]
# 4 fts
# lookback 25
# EXTREMA: [9, 18, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [142, 190, 214, 227]
# 4 fts
# lookback 25
# EXTREMA: [8, 17, 20, 24]
# 4 fts
# lookback 250
# EXTREMA: [141, 189, 213, 226]
# 4 fts
# lookback 25
# EXTREMA: [16, 19, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [140, 188, 212, 225]
# 4 fts
# lookback 25
# EXTREMA: [15, 18, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [139, 187, 211, 224]
# 4 fts
# lookback 25
# EXTREMA: [14, 17, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [138, 186, 210, 223]
# 4 fts
# lookback 25
# EXTREMA: [13, 16, 20, 22]
# 4 fts
# lookback 250
# EXTREMA: [137, 185, 209, 222]
# 4 fts
# lookback 25
# EXTREMA: [12, 15, 19, 25]
# 4 fts
# lookback 250
# EXTREMA: [136, 184, 208, 221]
# 4 fts
# lookback 25
# EXTREMA: [14, 18, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [135, 183, 207, 220]
# 4 fts
# lookback 25
# EXTREMA: [13, 17, 23, 24]
# 4 fts
# lookback 250
# EXTREMA: [134, 182, 206, 219]
# 4 fts
# lookback 25
# EXTREMA: [12, 16, 22, 23]
# 4 fts
# lookback 250
# EXTREMA: [133, 181, 205, 218]
# 4 fts
# lookback 25
# EXTREMA: [11, 15, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [132, 180, 204, 217]
# 4 fts
# lookback 25
# EXTREMA: [10, 14, 21, 25]
# 4 fts
# lookback 250
# EXTREMA: [131, 179, 203, 216]
# 4 fts
# lookback 25
# EXTREMA: [9, 13, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [178, 202, 215, 250]
# 4 fts
# lookback 25
# EXTREMA: [8, 12, 19, 25]
# 4 fts
# lookback 250
# EXTREMA: [177, 201, 214, 250]
# 4 fts
# lookback 25
# EXTREMA: [7, 11, 18, 24]
# 4 fts
# lookback 250
# EXTREMA: [176, 200, 213, 249]
# 4 fts
# lookback 25
# EXTREMA: [6, 10, 17, 23]
# 4 fts
# lookback 250
# EXTREMA: [175, 199, 212, 248]
# 4 fts
# lookback 25
# EXTREMA: [5, 9, 16, 22]
# 4 fts
# lookback 250
# EXTREMA: [174, 198, 211, 247]
# 4 fts
# lookback 25
# EXTREMA: [4, 8, 15, 21]
# 4 fts
# lookback 250
# EXTREMA: [173, 197, 210, 246]
# 4 fts
# lookback 25
# EXTREMA: [3, 7, 14, 20]
# 4 fts
# lookback 250
# EXTREMA: [172, 196, 209, 245]
# 4 fts
# lookback 25
# EXTREMA: [6, 13, 19, 25]
# 4 fts
# lookback 250
# EXTREMA: [171, 195, 208, 244]
# 4 fts
# lookback 25
# EXTREMA: [5, 12, 18, 25]
# 4 fts
# lookback 250
# EXTREMA: [170, 194, 207, 243]
# 4 fts
# lookback 25
# EXTREMA: [4, 11, 17, 24]
# 4 fts
# lookback 250
# EXTREMA: [169, 193, 206, 242]
# 4 fts
# lookback 25
# EXTREMA: [16, 21, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [168, 192, 205, 241]
# 4 fts
# lookback 25
# EXTREMA: [15, 20, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [191, 204, 240, 250]
# 4 fts
# lookback 25
# EXTREMA: [19, 22, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [190, 203, 239, 249]
# 4 fts
# lookback 25
# EXTREMA: [18, 21, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [189, 202, 238, 248]
# 4 fts
# lookback 25
# EXTREMA: [17, 20, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [188, 201, 237, 247]
# 4 fts
# lookback 25
# EXTREMA: [16, 19, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [187, 200, 236, 246]
# 4 fts
# lookback 25
# EXTREMA: [4, 10, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [186, 199, 235, 245]
# 4 fts
# lookback 25
# EXTREMA: [3, 9, 19, 24]
# 4 fts
# lookback 250
# EXTREMA: [185, 198, 234, 244]
# 4 fts
# lookback 25
# EXTREMA: [2, 8, 18, 23]
# 4 fts
# lookback 250
# EXTREMA: [184, 197, 233, 243]
# 4 fts
# lookback 25
# EXTREMA: [1, 7, 17, 22]
# 4 fts
# lookback 250
# EXTREMA: [183, 196, 232, 242]
# 4 fts
# lookback 25
# EXTREMA: [0, 6, 16, 25]
# 4 fts
# lookback 250
# EXTREMA: [182, 195, 231, 241]
# 4 fts
# lookback 25
# EXTREMA: [0, 5, 15, 25]
# 4 fts
# lookback 250
# EXTREMA: [181, 194, 230, 240]
# 4 fts
# lookback 25
# EXTREMA: [0, 4, 14, 25]
# 4 fts
# lookback 250
# EXTREMA: [180, 193, 229, 239]
# 4 fts
# lookback 25
# EXTREMA: [17, 21, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [179, 192, 228, 238]
# 4 fts
# lookback 25
# EXTREMA: [16, 20, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [178, 191, 227, 237]
# 4 fts
# lookback 25
# EXTREMA: [19, 23, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [177, 190, 226, 236]
# 4 fts
# lookback 25
# EXTREMA: [0, 10, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [176, 189, 225, 235]
# 4 fts
# lookback 25
# EXTREMA: [0, 9, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [175, 188, 224, 234]
# 4 fts
# lookback 25
# EXTREMA: [0, 8, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [174, 187, 223, 233]
# 4 fts
# lookback 25
# EXTREMA: [2, 7, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [173, 186, 222, 232]
# 4 fts
# lookback 25
# EXTREMA: [1, 6, 23, 24]
# 4 fts
# lookback 250
# EXTREMA: [172, 185, 221, 231]
# 4 fts
# lookback 25
# EXTREMA: [0, 5, 22, 23]
# 4 fts
# lookback 250
# EXTREMA: [171, 184, 220, 230]
# 4 fts
# lookback 25
# EXTREMA: [0, 4, 21, 22]
# 4 fts
# lookback 250
# EXTREMA: [170, 183, 219, 229]
# 4 fts
# lookback 25
# EXTREMA: [1, 3, 20, 21]
# 4 fts
# lookback 250
# EXTREMA: [169, 182, 218, 228]
# 4 fts
# lookback 25
# EXTREMA: [2, 19, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [96, 168, 227, 250]
# 4 fts
# lookback 25
# EXTREMA: [1, 18, 19, 24]
# 4 fts
# lookback 250
# EXTREMA: [95, 167, 226, 249]
# 4 fts
# lookback 25
# EXTREMA: [0, 17, 18, 25]
# 4 fts
# lookback 250
# EXTREMA: [94, 166, 225, 250]
# 4 fts
# lookback 25
# EXTREMA: [0, 16, 17, 25]
# 4 fts
# lookback 250
# EXTREMA: [93, 165, 224, 250]
# 4 fts
# lookback 25
# EXTREMA: [2, 15, 16, 24]
# 4 fts
# lookback 250
# EXTREMA: [92, 164, 223, 249]
# 4 fts
# lookback 25
# EXTREMA: [14, 15, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [91, 163, 222, 248]
# 4 fts
# lookback 25
# EXTREMA: [13, 14, 22, 24]
# 4 fts
# lookback 250
# EXTREMA: [90, 162, 221, 247]
# 4 fts
# lookback 25
# EXTREMA: [12, 13, 21, 23]
# 4 fts
# lookback 250
# EXTREMA: [89, 161, 220, 246]
# 4 fts
# lookback 25
# EXTREMA: [11, 12, 20, 22]
# 4 fts
# lookback 250
# EXTREMA: [88, 160, 219, 245]
# 4 fts
# lookback 25
# EXTREMA: [10, 11, 19, 21]
# 4 fts
# lookback 250
# EXTREMA: [87, 159, 218, 244]
# 4 fts
# lookback 25
# EXTREMA: [9, 10, 18, 20]
# 4 fts
# lookback 250
# EXTREMA: [86, 158, 217, 243]
# 4 fts
# lookback 25
# EXTREMA: [8, 9, 17, 19]
# 4 fts
# lookback 250
# EXTREMA: [85, 157, 216, 242]
# 4 fts
# lookback 25
# EXTREMA: [7, 8, 16, 18]
# 4 fts
# lookback 250
# EXTREMA: [84, 156, 215, 241]
# 4 fts
# lookback 25
# EXTREMA: [7, 15, 17, 25]
# 4 fts
# lookback 250
# EXTREMA: [83, 155, 214, 240]
# 4 fts
# lookback 25
# EXTREMA: [6, 14, 16, 24]
# 4 fts
# lookback 250
# EXTREMA: [82, 154, 213, 239]
# 4 fts
# lookback 25
# EXTREMA: [5, 13, 15, 23]
# 4 fts
# lookback 250
# EXTREMA: [81, 153, 212, 238]
# 4 fts
# lookback 25
# EXTREMA: [12, 14, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [80, 152, 211, 237]
# 4 fts
# lookback 25
# EXTREMA: [13, 21, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [79, 151, 210, 236]
# 4 fts
# lookback 25
# EXTREMA: [12, 20, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [78, 150, 209, 235]
# 4 fts
# lookback 25
# EXTREMA: [11, 19, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [77, 149, 208, 234]
# 4 fts
# lookback 25
# EXTREMA: [10, 18, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [76, 148, 207, 233]
# 4 fts
# lookback 25
# EXTREMA: [9, 17, 21, 24]
# 4 fts
# lookback 250
# EXTREMA: [75, 147, 206, 232]
# 4 fts
# lookback 25
# EXTREMA: [8, 16, 20, 23]
# 4 fts
# lookback 250
# EXTREMA: [74, 146, 205, 231]
# 4 fts
# lookback 25
# EXTREMA: [7, 15, 19, 22]
# 4 fts
# lookback 250
# EXTREMA: [73, 145, 204, 230]
# 4 fts
# lookback 25
# EXTREMA: [6, 14, 18, 25]
# 4 fts
# lookback 250
# EXTREMA: [72, 144, 203, 229]
# 4 fts
# lookback 25
# EXTREMA: [5, 13, 17, 25]
# 4 fts
# lookback 250
# EXTREMA: [71, 143, 202, 250]
# 4 fts
# lookback 25
# EXTREMA: [4, 12, 16, 24]
# 4 fts
# lookback 250
# EXTREMA: [70, 142, 201, 249]
# 4 fts
# lookback 25
# EXTREMA: [3, 11, 15, 23]
# 4 fts
# lookback 250
# EXTREMA: [69, 141, 200, 248]
# 4 fts
# lookback 25
# EXTREMA: [2, 10, 14, 22]
# 4 fts
# lookback 250
# EXTREMA: [68, 140, 199, 247]
# 4 fts
# lookback 25
# EXTREMA: [1, 9, 13, 21]
# 4 fts
# lookback 250
# EXTREMA: [67, 139, 198, 246]
# 4 fts
# lookback 25
# EXTREMA: [4, 8, 12, 25]
# 4 fts
# lookback 250
# EXTREMA: [66, 138, 197, 250]
# 4 fts
# lookback 25
# EXTREMA: [3, 7, 11, 25]
# 4 fts
# lookback 250
# EXTREMA: [65, 137, 196, 250]
# 4 fts
# lookback 25
# EXTREMA: [2, 6, 10, 24]
# 4 fts
# lookback 250
# EXTREMA: [64, 136, 195, 249]
# 4 fts
# lookback 25
# EXTREMA: [1, 5, 9, 23]
# 4 fts
# lookback 250
# EXTREMA: [63, 135, 194, 248]
# 4 fts
# lookback 25
# EXTREMA: [0, 4, 8, 22]
# 4 fts
# lookback 250
# EXTREMA: [62, 134, 193, 247]
# 4 fts
# lookback 25
# EXTREMA: [0, 3, 7, 21]
# 4 fts
# lookback 250
# EXTREMA: [61, 133, 192, 246]
# 4 fts
# lookback 25
# EXTREMA: [1, 2, 6, 20]
# 4 fts
# lookback 250
# EXTREMA: [60, 132, 191, 245]
# 4 fts
# lookback 25
# EXTREMA: [0, 1, 5, 19]
# 4 fts
# lookback 250
# EXTREMA: [59, 131, 190, 244]
# 4 fts
# lookback 25
# EXTREMA: [7, 12, 18, 25]
# 4 fts
# lookback 250
# EXTREMA: [58, 130, 189, 243]
# 4 fts
# lookback 25
# EXTREMA: [17, 21, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [57, 129, 188, 242]
# 4 fts
# lookback 25
# EXTREMA: [10, 16, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [56, 128, 187, 241]
# 4 fts
# lookback 25
# EXTREMA: [15, 22, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [55, 127, 186, 240]
# 4 fts
# lookback 25
# EXTREMA: [14, 21, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [54, 126, 185, 239]
# 4 fts
# lookback 25
# EXTREMA: [13, 20, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [53, 125, 184, 238]
# 4 fts
# lookback 25
# EXTREMA: [3, 12, 24, 25]
# 4 fts
# lookback 250
# EXTREMA: [52, 124, 183, 237]
# 4 fts
# lookback 25
# EXTREMA: [2, 11, 23, 25]
# 4 fts
# lookback 250
# EXTREMA: [51, 123, 182, 250]
# 4 fts
# lookback 25
# EXTREMA: [1, 10, 22, 25]
# 4 fts
# lookback 250
# EXTREMA: [50, 122, 181, 250]
# 4 fts
# lookback 25
# EXTREMA: [0, 9, 21, 24]
# 4 fts
# lookback 250
# EXTREMA: [49, 121, 180, 249]
# 4 fts
# lookback 25
# EXTREMA: [0, 8, 20, 23]
# 4 fts
# lookback 250
# EXTREMA: [48, 120, 179, 248]
# 4 fts
# lookback 25
# EXTREMA: [2, 7, 19, 22]
# 4 fts
# lookback 250
# EXTREMA: [47, 119, 178, 247]
# 4 fts
# lookback 25
# EXTREMA: [1, 6, 18, 21]
# 4 fts
# lookback 250
# EXTREMA: [46, 118, 177, 246]
# 4 fts
# lookback 25
# EXTREMA: [5, 17, 20, 25]
# 4 fts
# lookback 250
# EXTREMA: [45, 117, 176, 245]
# 4 fts
#    Unnamed: 0                Open_time     Open     High      Low    Close  \
# 0     13374.0  2023-07-12 04:00:32.256  1879.56  1882.00  1877.59  1881.99
# 1     13375.0  2023-07-12 04:59:31.200  1881.99  1884.98  1881.16  1882.99
# 2     13376.0  2023-07-12 06:00:41.216  1883.00  1896.43  1880.33  1889.26
# 3     13377.0  2023-07-12 06:59:40.160  1889.26  1894.95  1888.67  1889.99
# 4     13378.0  2023-07-12 08:00:50.176  1890.00  1891.37  1885.67  1888.09
#
#        Volume    Close_time  Quote_asset_volume  Number_of_trades  ...  \
# 0   35051.697  1.689138e+12        6.589124e+07           40856.0  ...
# 1   39292.282  1.689142e+12        7.398676e+07           57073.0  ...
# 2  171428.110  1.689145e+12        3.239126e+08          128290.0  ...
# 3   82915.804  1.689149e+12        1.568477e+08           81961.0  ...
# 4   60671.379  1.689152e+12        1.145432e+08           59742.0  ...
#
#    Feature_25_3  Feature_25_4  Feature_250_1  Feature_250_2  Feature_250_3  \
# 0           NaN           NaN            NaN            NaN            NaN
# 1           NaN           NaN            NaN            NaN            NaN
# 2           NaN           NaN            NaN            NaN            NaN
# 3           NaN           NaN            NaN            NaN            NaN
# 4           NaN           NaN            NaN            NaN            NaN
#
#    Feature_250_4  Feature_1000_1  Feature_1000_2  Feature_1000_3  \
# 0            NaN             NaN             NaN             NaN
# 1            NaN             NaN             NaN             NaN
# 2            NaN             NaN             NaN             NaN
# 3            NaN             NaN             NaN             NaN
# 4            NaN             NaN             NaN             NaN
#
#    Feature_1000_4
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 25 columns]

# %%
## multifeatures

def extract_segment_features(segment, feature_extractors, column_name="Close"):
    """Extract multiple features for a given segment of data.
    
    Parameters:
    - segment: Segment of the DataFrame
    - feature_extractors: List of feature extraction functions
    - column_name: Name of the column to extract features from
    
    Returns:
    - features: List of extracted features for the segment
    """
    return [feature_extractor(segment, column_name) for feature_extractor in feature_extractors]

def process_row_updated(df, idx, lookback, feature_extractors, column_name="Close"):
    """Updated version to process a single row to extract features based on lookback.
    
    Parameters:
    - df: DataFrame containing the data
    - idx: Index of the row to process
    - lookback: Length of the lookback period
    - feature_extractors: List of feature extraction functions
    - column_name: Name of the column to extract features from
    
    Returns:
    - features: Extracted features for the row
    """
    # Get the lookback window for the current index
    start_idx = max(0, idx - lookback)
    window_df = df.iloc[start_idx:idx+1].copy()
    
    # Reset the indices of the window dataframe
    window_df.reset_index(drop=True, inplace=True)
    
    # Normalize the Close prices within the window
    min_val = window_df[column_name].min()
    max_val = window_df[column_name].max()
    window_df["Normalized"] = (window_df[column_name] - min_val) / (max_val - min_val)
    
    # Find refined highs and lows
    highs = refine_highs(window_df, "Normalized", 4)
    lows = refine_lows(window_df, "Normalized", 4)
    
    # Combine and sort highs and lows to create segments
    extremas = sorted(highs + lows)[-4:]  # Only consider the last 4 extremas
    
    # Extract features for each segment
    all_features = []
    for i in range(len(extremas) - 1):
        segment = window_df.iloc[extremas[i]:extremas[i+1]]
        features = extract_segment_features(segment, feature_extractors)
        all_features.extend(features)
    
    # Include the segment from the last extrema to the end of the lookback window
    if extremas:
        segment = window_df.iloc[extremas[-1]:]
        features = extract_segment_features(segment, feature_extractors)
        all_features.extend(features)
    
    # If no segments were found, return NaN
    if not all_features:
        return [None] * len(extremas) * len(feature_extractors)
    
    return all_features

def extract_features_from_df_updated(df, lookbacks=[25, 250, 1000], feature_extractors=[mean_pct_change], column_name="Close"):
    """Updated version to extract features from the DataFrame for each lookback period.
    
    Parameters:
    - df: DataFrame containing the data
    - lookbacks: List of lookback periods
    - feature_extractors: List of feature extraction functions
    - column_name: Name of the column to extract features from
    
    Returns:
    - df: DataFrame augmented with extracted features
    """
    features_data = []

    for i in range(len(df)):
        row_features = {}
        for lookback in lookbacks:
            if i <= lookback:
                continue
            features = process_row_updated(df, i, lookback, feature_extractors, column_name)
            for j, feature in enumerate(features, 1):
                row_features[f"Feature_{lookback}_{j}"] = feature
        features_data.append(row_features)

    features_df = pd.DataFrame(features_data)
    augmented_df = pd.concat([df, features_df], axis=1)

    return augmented_df

import numpy as np
from scipy.stats import skew, kurtosis

# Additional feature extractor functions

def mean_value(df, column_name):
    """Calculate the mean value of a column."""
    return df[column_name].mean()

def median_value(df, column_name):
    """Calculate the median value of a column."""
    return df[column_name].median()

def variance_value(df, column_name):
    """Calculate the variance of a column."""
    return df[column_name].var()

def std_dev_value(df, column_name):
    """Calculate the standard deviation of a column."""
    return df[column_name].std()

def skewness_value(df, column_name):
    """Calculate the skewness of a column."""
    return skew(df[column_name])

def kurtosis_value(df, column_name):
    """Calculate the kurtosis of a column."""
    return kurtosis(df[column_name])

def mean_pct_change(df, column_name):
    """Calculate the mean percentage change of a column."""
    return df[column_name].pct_change().mean()

# Expand the list of feature extractor functions

# Re-run the feature extraction process using the extended feature extractors
augmented_df_extended = extract_features_from_df_updated(df, lookbacks=[24, 7*24], feature_extractors=feature_extractors_extended)

# Display the augmented DataFrame with the extracted features
augmented_df_extended.tail()
# Out:
#        Unnamed: 0                Open_time     Open     High      Low  \
# 13866       13870  2023-08-11 18:59:42.720  1843.95  1844.61  1841.64
# 13867       13871  2023-08-11 20:00:52.736  1843.98  1845.10  1843.22
# 13868       13872  2023-08-11 20:59:51.680  1845.10  1845.84  1843.00
# 13869       13873  2023-08-11 22:01:01.696  1844.82  1846.67  1844.27
# 13870       13874  2023-08-11 23:00:00.640  1845.73  1851.58  1845.31
#
#          Close     Volume     Close_time  Quote_asset_volume  \
# 13866  1843.97  24912.983  1691783999999        4.592308e+07
# 13867  1845.09  18963.405  1691787599999        3.497073e+07
# 13868  1844.83  14427.807  1691791199999        2.661282e+07
# 13869  1845.72  12951.209  1691794799999        2.390141e+07
# 13870  1848.04  38004.132  1691798399999        7.024763e+07
#
#        Number_of_trades  ...  Feature_24_7  Feature_24_8  Feature_168_1  \
# 13866             23582  ...      0.000535      1.128819       0.000476
# 13867             18530  ...      0.000559      1.283563       0.000476
# 13868             18769  ...      0.000384      1.211994       0.000476
# 13869             14867  ...           NaN           NaN       0.000476
# 13870             29909  ...           NaN           NaN       0.000476
#
#        Feature_168_2  Feature_168_3  Feature_168_4  Feature_168_5  \
# 13866       2.553517      -0.000218       6.770356      -0.000549
# 13867       2.553517      -0.000218       6.770356      -0.000549
# 13868       2.553517      -0.000218       6.770356      -0.000549
# 13869       2.553517      -0.000218       6.770356      -0.000549
# 13870       2.553517      -0.000218       6.770356      -0.000549
#
#        Feature_168_6  Feature_168_7  Feature_168_8
# 13866       6.633324       0.000535       1.128819
# 13867       6.633324       0.000559       1.283563
# 13868       6.633324       0.000384       1.211994
# 13869       6.633324       0.000404       1.299191
# 13870       6.633324       0.000546       1.857305
#
# [5 rows x 29 columns]

# %%
### also extract volume features

import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

# Load the data
#df = pd.read_csv('/mnt/data/eth1h.csv')
truncated_df = df.iloc[-1000:].reset_index(drop=True)
# Implementing the changes for volume features extraction based on the highs and lows from close prices
# Volumen feature extractor functions

def total_volume(df, column_name="Volume"):
    """Calculate the total volume for the segment."""
    return df[column_name].sum()

def mean_volume(df, column_name="Volume"):
    """Calculate the mean volume for the segment."""
    return df[column_name].mean()

def volume_variance(df, column_name="Volume"):
    """Calculate the variance of the volume for the segment."""
    return df[column_name].var()

def volume_std_dev(df, column_name="Volume"):
    """Calculate the standard deviation of the volume for the segment."""
    return df[column_name].std()

def volume_skewness(df, column_name="Volume"):
    """Calculate the skewness of the volume for the segment."""
    return skew(df[column_name])

def volume_kurtosis(df, column_name="Volume"):
    """Calculate the kurtosis of the volume for the segment."""
    return kurtosis(df[column_name])

def process_row_volume(df, idx, lookback, feature_extractors, volume_feature_extractors, column_name="Close", volume_column_name="Volume"):
    """Process a single row to extract features based on lookback for both price and volume.
    
    Parameters:
    - df: DataFrame containing the data
    - idx: Index of the row to process
    - lookback: Length of the lookback period
    - feature_extractors: List of feature extraction functions for price
    - volume_feature_extractors: List of feature extraction functions for volume
    - column_name: Name of the column to extract price features from
    - volume_column_name: Name of the column to extract volume features from
    
    Returns:
    - features: Extracted features for the row
    """
    # Get the lookback window for the current index
    start_idx = max(0, idx - lookback)
    window_df = df.iloc[start_idx:idx+1].copy()
    
    # Reset the indices of the window dataframe
    window_df.reset_index(drop=True, inplace=True)
    
    # Normalize the Close prices within the window
    min_val = window_df[column_name].min()
    max_val = window_df[column_name].max()
    window_df["Normalized"] = (window_df[column_name] - min_val) / (max_val - min_val)
    
    # Find refined highs and lows
    highs = refine_highs(window_df, "Normalized", 4)
    lows = refine_lows(window_df, "Normalized", 4)
    
    # Combine and sort highs and lows to create segments
    extremas = sorted(highs + lows)[-4:]  # Only consider the last 4 extremas
    
    # Extract features for each segment
    all_features = []
    for i in range(len(extremas) - 1):
        segment = window_df.iloc[extremas[i]:extremas[i+1]]
        features = extract_segment_features(segment, feature_extractors)
        volume_features = extract_segment_features(segment, volume_feature_extractors, column_name=volume_column_name)
        all_features.extend(features + volume_features)
    
    # Include the segment from the last extrema to the end of the lookback window
    if extremas:
        segment = window_df.iloc[extremas[-1]:]
        features = extract_segment_features(segment, feature_extractors)
        volume_features = extract_segment_features(segment, volume_feature_extractors, column_name=volume_column_name)
        all_features.extend(features + volume_features)
    
    # If no segments were found, return NaN
    if not all_features:
        return [None] * len(extremas) * (len(feature_extractors) + len(volume_feature_extractors))
    
    return all_features

def process_row_volume_updated(df, idx, lookback, feature_extractors, volume_feature_extractors, column_name="Close", volume_column_name="Volume"):
    """Process a single row to extract features based on lookback for both price and volume.
    
    Parameters:
    - df: DataFrame containing the data
    - idx: Index of the row to process
    - lookback: Length of the lookback period
    - feature_extractors: List of feature extraction functions for price
    - column_name: Name of the column to extract price features from
    - volume_column_name: Name of the column to extract volume features from
    
    Returns:
    - features: Extracted features for the row
    """
    # Get the lookback window for the current index
    start_idx = max(0, idx - lookback)
    window_df = df.iloc[start_idx:idx+1].copy()
    
    # Reset the indices of the window dataframe
    window_df.reset_index(drop=True, inplace=True)
    
    # Normalize the Close prices within the window
    min_val = window_df[column_name].min()
    max_val = window_df[column_name].max()
    window_df["Normalized"] = (window_df[column_name] - min_val) / (max_val - min_val)
    
    # Find refined highs and lows
    highs = refine_highs(window_df, "Normalized", 4)
    lows = refine_lows(window_df, "Normalized", 4)
    
    # Combine and sort highs and lows to create segments
    extremas = sorted(highs + lows)[-4:]  # Only consider the last 4 extremas
    
    # Extract features for each segment
    all_features = []
    for i in range(len(extremas) - 1):
        segment = window_df.iloc[extremas[i]:extremas[i+1]]
        features = extract_segment_features(segment, feature_extractors)
        volume_features = extract_segment_features(segment, volume_feature_extractors, column_name=volume_column_name)
        all_features.extend(features + volume_features)
    
    # Include the segment from the last extrema to the end of the lookback window
    if extremas:
        segment = window_df.iloc[extremas[-1]:]
        features = extract_segment_features(segment, feature_extractors)
        volume_features = extract_segment_features(segment, volume_feature_extractors, column_name=volume_column_name)
        all_features.extend(features + volume_features)
    
    ## add relative prices to extrema
    rel_prices = [window_df.iloc[ex]["Normalized"] - window_df.iloc[-1]["Normalized"]  for ex in extremas]
    all_features.extend(rel_prices)
    
    ## extrema values
    extrema_prices = [window_df.iloc[ex]["Normalized"] for ex in extremas]
    all_features.extend(extrema_prices)
    
    # If no segments were found, return NaN
    if not all_features:
        return [None] * len(extremas) * ((len(feature_extractors) + len(volume_feature_extractors)) + len(rel_prices) + len(extrema_prices))
    
    return all_features

# Provided utility functions
def find_highs(df, column_name):
    highs = []
    if df[column_name].iloc[0] > df[column_name].iloc[1]:
        highs.append(df.index[0])
    for i in range(1, len(df) - 1):
        if df[column_name].iloc[i] > df[column_name].iloc[i-1] and df[column_name].iloc[i] > df[column_name].iloc[i+1]:
            highs.append(df.index[i])
    if df[column_name].iloc[-1] > df[column_name].iloc[-2]:
        highs.append(df.index[-1])
    return highs

def find_lows(df, column_name):
    lows = []
    if df[column_name].iloc[0] < df[column_name].iloc[1]:
        lows.append(df.index[0])
    for i in range(1, len(df) - 1):
        if df[column_name].iloc[i] < df[column_name].iloc[i-1] and df[column_name].iloc[i] < df[column_name].iloc[i+1]:
            lows.append(df.index[i])
    if df[column_name].iloc[-1] < df[column_name].iloc[-2]:
        lows.append(df.index[-1])
    return lows

def refine_highs(df, column_name, target_length, min_length=2):
    refined_highs = find_highs(df, column_name)
    while len(refined_highs) > target_length:
        last_refined_highs = refined_highs
        refined_highs = find_highs(df.iloc[refined_highs], column_name)
        if len(refined_highs) < min_length:
            refined_highs = last_refined_highs
            break
    return refined_highs

def refine_lows(df, column_name, target_length, min_length=2):
    refined_lows = find_lows(df, column_name)
    while len(refined_lows) > target_length:
        last_refined_lows = refined_lows
        refined_lows = find_lows(df.iloc[refined_lows], column_name)
        if len(refined_lows) < min_length:
            refined_lows = last_refined_lows
            break
    return refined_lows

# The provided code
def extract_segment_features(segment, feature_extractors, column_name="Close"):
    return [feature_extractor(segment, column_name) for feature_extractor in feature_extractors]

def extract_features_from_df_updated(df, lookbacks=[25, 250, 1000], feature_extractors=[mean_pct_change], volume_feature_extractors=[], column_name="Close"):
    features_data = []
    for i in range(len(df)):
        row_features = {}
        for lookback in lookbacks:
            if i <= lookback:
                continue
            features = process_row_volume_updated(df, i, lookback, feature_extractors,volume_feature_extractors, column_name)
            for j, feature in enumerate(features, 1):
                row_features[f"Feature_{lookback}_{j}"] = feature
        features_data.append(row_features)
    features_df = pd.DataFrame(features_data)
    augmented_df = pd.concat([df, features_df], axis=1)
    return augmented_df

# Extended list of feature extractor functions for volume
volume_feature_extractors = [
    total_volume,
    mean_volume,
    mean_volume
]
feature_extractors_extended = [
    mean_pct_change, 
    std_dev_value, 
]


# Re-run the feature extraction process using the extended feature extractors for volume
augmented_df_volume_updated = extract_features_from_df_updated(df, lookbacks=[24, 4*24, 14*24], feature_extractors=feature_extractors_extended, volume_feature_extractors=volume_feature_extractors)

# Display the augmented DataFrame with the extracted features
augmented_df_volume_updated.tail()

# %%
augmented_df_volume_updated

# %%
augmented_df_volume_updated.to_csv("1h_ETH_withFeatures_v0.csvo")

# %%
## todo exxtract features for volume too, define different feature extractor lists ...
# add distances to extrema, normalized extrema values itself, extract same features from detrended
